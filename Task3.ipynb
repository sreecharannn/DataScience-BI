# %% [markdown]
# #Number Recognition
# Handwritten digit recognition system not only detects
# scanned images of handwritten digits.Handwritten digit
# recognition using MNIST dataset is a major project made
# with the help of Neural Network. It basically detects
# the scanned images of handwritten digits.

# %%
#import all libraries
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load and preprocess the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Display some sample images
plt.figure(figsize=(5, 3))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(f"Label: {y_train[i]}")
    plt.axis('off')
    #plt.tight_layout()
plt.show()

# %%
# Build and compile the model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(x_train, y_train, epochs=15)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0660 - accuracy: 0.9790
# Epoch 2/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0582 - accuracy: 0.9812
# Epoch 3/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0530 - accuracy: 0.9823
# Epoch 4/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0480 - accuracy: 0.9838
# Epoch 5/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0446 - accuracy: 0.9855
# Epoch 6/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0422 - accuracy: 0.9860
# Epoch 7/15
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0380 - accuracy: 0.9869
# Epoch 8/15
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0369 - accuracy: 0.9879
# Epoch 9/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0351 - accuracy: 0.9881
# Epoch 10/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0325 - accuracy: 0.9887
# Epoch 11/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0313 - accuracy: 0.9894
# Epoch 12/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0287 - accuracy: 0.9900
# Epoch 13/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0277 - accuracy: 0.9908
# Epoch 14/15
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0273 - accuracy: 0.9907
# Epoch 15/15
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0274 - accuracy: 0.9904

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print("\nTest accuracy:", test_acc)
# Out:
# 313/313 - 1s - loss: 0.0708 - accuracy: 0.9822 - 646ms/epoch - 2ms/step
#
# Test accuracy: 0.982200026512146

# %%
# Make and Visualize predictions
predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)

plt.figure(figsize=(10,5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_test[i], cmap='gray')
    plt.title(f"Pred: {predicted_labels[i]}, Actual: {y_test[i]}")
    plt.axis('off')
plt.show()
# Out:
# 313/313 [==============================] - 0s 1ms/step
